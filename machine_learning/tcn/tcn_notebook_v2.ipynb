# %%
import sys
import os
PROJECT_ROOT = os.path.abspath('../..')
sys.path.append(PROJECT_ROOT)

# AJUSTA ESTOS IMPORTS a tu proyecto real:
from machine_learning.data_collectors import build_ml_dataframe, build_supervised_dataset
from machine_learning.evaluators import eval_regression_extended

from machine_learning.tcn.train_tcn import train_eval_tcn, TrainTCNConfig
from machine_learning.artifacts import load_model_artifact_auto

from machine_learning.data_collectors import (
    build_ml_dataframe,
    build_supervised_dataset,
    time_split_masks,
    purged_ts_cv_splits,
    TARGET_HORIZONS,
    TARGET_LOOKBACKS,
    parse_feat_lag
)
from database_tier1 import TARGET_STOCKS
from python_scripts.LLM_analysis.preprocess_store_database import get_connection

import pandas as pd

from train_walk_forward_tcn import run_walk_forward_tcn, ExperimentConfig, TrainHP
from walk_forward import WalkForwardConfig
# Out:
# [DB_PATH_DEFAULT] /workspace/finance-modelling/data/stock_data.db
# {'foreign_keys': 1, 'journal_mode': 'wal', 'synchronous': 1}

# %%
# 1) Cargar datos (long: symbol, timestamp, OHLCV, indicadores, etc.)
conn = get_connection()

timeframe = "1Day"
symbols = TARGET_STOCKS

start = None
end = None

include_indicators = False
indicator_names = []
# indicator_names = ['RSI_14', 'BBB_20_2.0', 'BBP_20_2.0', 'ATRr_14']

include_economic_indicators = False
econ_indicator_names = []
# econ_indicator_names = ['CPI', 'UNEMPLOYMENT']

include_fmp = False
fmp_feature_names = []
keep_fmp_asof_date = False
fmp_prefix = 'fmp'

# -----------------------
# ELIGE LOOKBACK AQUÍ
# -----------------------
lookback = TARGET_LOOKBACKS[3]  # <-- cámbialo

# 3 horizontes baseline (puedes editar)
#horizons = [5, 20, 60]
horizon = TARGET_HORIZONS[2]

base_feature_cols = ['open', 'high', 'low', 'close', 'volume', 'trade_count']

lags_by_feature = None
default_lags = lookback


feature_cols = base_feature_cols + indicator_names + econ_indicator_names + fmp_feature_names


print(f"lb={lookback}, h={horizon}")
# Out:
# lb=252, h=20

# %%
df = build_ml_dataframe(
    conn,
    symbols=symbols,
    timeframe="1Day",
    start="2015-01-01",
    end="2025-12-31",
    include_indicators=True,
    include_econ=True,
    include_fmp=False,
)

# 2) feature_cols (excluir no-features)
non_feature_cols = {"symbol", "timestamp", "timeframe"}
feature_cols = [c for c in df.columns if c not in non_feature_cols]

# 3) Sanity check explícito: build_supervised_dataset clásico (horizon=5, lags_by_feature=None)
X_wide_5, y_5, meta_5 = build_supervised_dataset(
    df,
    feature_cols=feature_cols,
    lookback=60,
    horizon=5,
    price_col="close",
    group_col="symbol",
    timestamp_col="timestamp",
    lags_by_feature=None,   # explícito, como pediste
)
print("Sanity check horizon=5:", X_wide_5.shape, y_5.shape, meta_5.columns)
assert "target_timestamp" in meta_5.columns, "meta debe incluir target_timestamp"
# Out:
# Sanity check horizon=5: (198102, 420) (198102,) Index(['symbol', 'timestamp', 'target_timestamp'], dtype='str')

# %%
# 4) Walk-forward + TCN
cfg = ExperimentConfig(
    lookback=TARGET_LOOKBACKS[3],
    horizons=(5, 20, 60),
    wf=WalkForwardConfig(
        target_col="target_timestamp",
        train_span=252*5,   # rolling 5 años (en target timestamps)
        val_span=256,       # 6m
        test_span=256,      # 6m
        step_span=256,      # reentreno semestral
        embargo_span=0,
        min_train_span=252*3,
    ),
    seed=0,
    run_base_dir="../runs",
    run_name=None,
    device="cuda",
    train_hp=TrainHP(num_workers=8, pin_memory=True),
    timeframe="1Day"
)

# (Opcional) selección simple de hiperparámetros (ejemplo: probar ic_lambda)
hp_candidates = [
    {"loss_hp": {"ic_lambda": 0.0}},   # solo SmoothL1
    {"loss_hp": {"ic_lambda": 0.2}},   # SmoothL1 + IC loss
]

out = run_walk_forward_tcn(
    df,
    feature_cols=feature_cols,
    build_supervised_dataset_fn=build_supervised_dataset,
    eval_fn=eval_regression_extended,
    cfg=cfg,
    hp_candidates=hp_candidates,
)

print("run_dir:", out["run_dir"])
print("final verify diffs:", out["final"]["verify"])
print("tabla folds:\n", out["agg_table"])
# Out:
# === Hyperparam selection (val mean DailyIC promedio en folds) ===
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 01][epoch 001] train_loss=0.008708 | val_mean_dailyIC=0.012250 | best=0.012250@1 | no_improve=0time_train=9.2s time_valpred=1.1s time_score=0.2s total=10.5s
# [fold 01][epoch 002] train_loss=0.006032 | val_mean_dailyIC=0.024320 | best=0.024320@2 | no_improve=0time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 01][epoch 003] train_loss=0.005894 | val_mean_dailyIC=-0.036021 | best=0.024320@2 | no_improve=1time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 01][epoch 004] train_loss=0.005881 | val_mean_dailyIC=0.022169 | best=0.024320@2 | no_improve=2time_train=7.0s time_valpred=1.0s time_score=0.1s total=8.1s
# [fold 01][epoch 005] train_loss=0.005796 | val_mean_dailyIC=0.036694 | best=0.036694@5 | no_improve=0time_train=7.2s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 01][epoch 006] train_loss=0.005758 | val_mean_dailyIC=-0.007090 | best=0.036694@5 | no_improve=1time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 01][epoch 007] train_loss=0.005762 | val_mean_dailyIC=-0.002279 | best=0.036694@5 | no_improve=2time_train=7.2s time_valpred=1.7s time_score=0.1s total=9.0s
# [fold 01][epoch 008] train_loss=0.005699 | val_mean_dailyIC=0.031757 | best=0.036694@5 | no_improve=3time_train=7.1s time_valpred=1.2s time_score=0.1s total=8.4s
# [fold 01][epoch 009] train_loss=0.005636 | val_mean_dailyIC=0.007396 | best=0.036694@5 | no_improve=4time_train=7.6s time_valpred=1.3s time_score=0.3s total=9.2s
# [fold 01][epoch 010] train_loss=0.005598 | val_mean_dailyIC=0.032229 | best=0.036694@5 | no_improve=5time_train=7.1s time_valpred=1.0s time_score=0.2s total=8.4s
# [fold 01][epoch 011] train_loss=0.005514 | val_mean_dailyIC=0.029788 | best=0.036694@5 | no_improve=6time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.7s
# [fold 01][epoch 012] train_loss=0.005458 | val_mean_dailyIC=0.021915 | best=0.036694@5 | no_improve=7time_train=7.0s time_valpred=1.1s time_score=0.1s total=8.2s
# [fold 01][epoch 013] train_loss=0.005384 | val_mean_dailyIC=0.006442 | best=0.036694@5 | no_improve=8time_train=7.6s time_valpred=1.0s time_score=0.1s total=8.7s
# [fold 01][epoch 014] train_loss=0.005327 | val_mean_dailyIC=-0.032892 | best=0.036694@5 | no_improve=9time_train=8.4s time_valpred=1.5s time_score=0.1s total=10.0s
# [fold 01][epoch 015] train_loss=0.005302 | val_mean_dailyIC=0.028373 | best=0.036694@5 | no_improve=10time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 01] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 02][epoch 001] train_loss=0.009544 | val_mean_dailyIC=0.015425 | best=0.015425@1 | no_improve=0time_train=7.0s time_valpred=1.1s time_score=0.1s total=8.2s
# [fold 02][epoch 002] train_loss=0.007667 | val_mean_dailyIC=0.013969 | best=0.015425@1 | no_improve=1time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.5s
# [fold 02][epoch 003] train_loss=0.007668 | val_mean_dailyIC=0.034580 | best=0.034580@3 | no_improve=0time_train=7.4s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 02][epoch 004] train_loss=0.007545 | val_mean_dailyIC=0.009880 | best=0.034580@3 | no_improve=1time_train=7.4s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 02][epoch 005] train_loss=0.007463 | val_mean_dailyIC=0.010865 | best=0.034580@3 | no_improve=2time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 02][epoch 006] train_loss=0.007406 | val_mean_dailyIC=0.043394 | best=0.043394@6 | no_improve=0time_train=6.9s time_valpred=1.0s time_score=0.1s total=8.1s
# [fold 02][epoch 007] train_loss=0.007265 | val_mean_dailyIC=0.025339 | best=0.043394@6 | no_improve=1time_train=7.6s time_valpred=1.1s time_score=0.1s total=8.8s
# [fold 02][epoch 008] train_loss=0.007263 | val_mean_dailyIC=0.054686 | best=0.054686@8 | no_improve=0time_train=6.9s time_valpred=1.0s time_score=0.1s total=8.1s
# [fold 02][epoch 009] train_loss=0.007167 | val_mean_dailyIC=0.059772 | best=0.059772@9 | no_improve=0time_train=7.4s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 02][epoch 010] train_loss=0.007096 | val_mean_dailyIC=0.036923 | best=0.059772@9 | no_improve=1time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 02][epoch 011] train_loss=0.006989 | val_mean_dailyIC=0.023103 | best=0.059772@9 | no_improve=2time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 02][epoch 012] train_loss=0.006937 | val_mean_dailyIC=0.058149 | best=0.059772@9 | no_improve=3time_train=6.8s time_valpred=1.1s time_score=0.1s total=7.9s
# [fold 02][epoch 013] train_loss=0.006854 | val_mean_dailyIC=0.024398 | best=0.059772@9 | no_improve=4time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 02][epoch 014] train_loss=0.006752 | val_mean_dailyIC=0.031845 | best=0.059772@9 | no_improve=5time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 02][epoch 015] train_loss=0.006710 | val_mean_dailyIC=0.040336 | best=0.059772@9 | no_improve=6time_train=7.2s time_valpred=1.2s time_score=0.1s total=8.5s
# [fold 02][epoch 016] train_loss=0.006612 | val_mean_dailyIC=0.019263 | best=0.059772@9 | no_improve=7time_train=7.1s time_valpred=1.4s time_score=0.3s total=8.8s
# [fold 02][epoch 017] train_loss=0.006563 | val_mean_dailyIC=0.026522 | best=0.059772@9 | no_improve=8time_train=7.0s time_valpred=1.1s time_score=0.1s total=8.3s
# [fold 02][epoch 018] train_loss=0.006515 | val_mean_dailyIC=0.015352 | best=0.059772@9 | no_improve=9time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 02][epoch 019] train_loss=0.006420 | val_mean_dailyIC=0.022463 | best=0.059772@9 | no_improve=10time_train=7.3s time_valpred=1.3s time_score=0.1s total=8.8s
# [fold 02] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 03][epoch 001] train_loss=0.010699 | val_mean_dailyIC=0.010574 | best=0.010574@1 | no_improve=0time_train=7.4s time_valpred=1.0s time_score=0.1s total=8.5s
# [fold 03][epoch 002] train_loss=0.008217 | val_mean_dailyIC=-0.033856 | best=0.010574@1 | no_improve=1time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 03][epoch 003] train_loss=0.008264 | val_mean_dailyIC=0.049062 | best=0.049062@3 | no_improve=0time_train=7.0s time_valpred=1.1s time_score=0.1s total=8.2s
# [fold 03][epoch 004] train_loss=0.008127 | val_mean_dailyIC=-0.015066 | best=0.049062@3 | no_improve=1time_train=8.2s time_valpred=1.4s time_score=0.1s total=9.8s
# [fold 03][epoch 005] train_loss=0.008064 | val_mean_dailyIC=0.008739 | best=0.049062@3 | no_improve=2time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 03][epoch 006] train_loss=0.008078 | val_mean_dailyIC=-0.010827 | best=0.049062@3 | no_improve=3time_train=7.9s time_valpred=1.4s time_score=0.1s total=9.4s
# [fold 03][epoch 007] train_loss=0.008016 | val_mean_dailyIC=0.011072 | best=0.049062@3 | no_improve=4time_train=9.1s time_valpred=1.2s time_score=0.1s total=10.4s
# [fold 03][epoch 008] train_loss=0.007975 | val_mean_dailyIC=-0.037929 | best=0.049062@3 | no_improve=5time_train=7.6s time_valpred=1.0s time_score=0.1s total=8.8s
# [fold 03][epoch 009] train_loss=0.007895 | val_mean_dailyIC=-0.013444 | best=0.049062@3 | no_improve=6time_train=7.0s time_valpred=1.0s time_score=0.1s total=8.1s
# [fold 03][epoch 010] train_loss=0.007834 | val_mean_dailyIC=0.024812 | best=0.049062@3 | no_improve=7time_train=8.2s time_valpred=1.3s time_score=0.1s total=9.7s
# [fold 03][epoch 011] train_loss=0.007838 | val_mean_dailyIC=0.043303 | best=0.049062@3 | no_improve=8time_train=8.9s time_valpred=1.4s time_score=0.1s total=10.5s
# [fold 03][epoch 012] train_loss=0.007759 | val_mean_dailyIC=0.036039 | best=0.049062@3 | no_improve=9time_train=7.9s time_valpred=1.0s time_score=0.1s total=9.1s
# [fold 03][epoch 013] train_loss=0.007685 | val_mean_dailyIC=0.007971 | best=0.049062@3 | no_improve=10time_train=8.0s time_valpred=1.3s time_score=0.2s total=9.4s
# [fold 03] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 04][epoch 001] train_loss=0.010095 | val_mean_dailyIC=-0.019329 | best=-0.019329@1 | no_improve=0time_train=8.7s time_valpred=1.1s time_score=0.1s total=9.9s
# [fold 04][epoch 002] train_loss=0.008413 | val_mean_dailyIC=-0.013897 | best=-0.013897@2 | no_improve=0time_train=7.0s time_valpred=1.0s time_score=0.2s total=8.3s
# [fold 04][epoch 003] train_loss=0.008340 | val_mean_dailyIC=-0.040294 | best=-0.013897@2 | no_improve=1time_train=7.4s time_valpred=1.0s time_score=0.2s total=8.6s
# [fold 04][epoch 004] train_loss=0.008300 | val_mean_dailyIC=-0.073138 | best=-0.013897@2 | no_improve=2time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 04][epoch 005] train_loss=0.008190 | val_mean_dailyIC=-0.016034 | best=-0.013897@2 | no_improve=3time_train=8.3s time_valpred=1.1s time_score=0.1s total=9.6s
# [fold 04][epoch 006] train_loss=0.008128 | val_mean_dailyIC=-0.023099 | best=-0.013897@2 | no_improve=4time_train=7.8s time_valpred=1.2s time_score=0.1s total=9.2s
# [fold 04][epoch 007] train_loss=0.008114 | val_mean_dailyIC=0.007792 | best=0.007792@7 | no_improve=0time_train=7.5s time_valpred=1.2s time_score=0.1s total=8.8s
# [fold 04][epoch 008] train_loss=0.008056 | val_mean_dailyIC=-0.012854 | best=0.007792@7 | no_improve=1time_train=7.5s time_valpred=1.3s time_score=0.1s total=8.9s
# [fold 04][epoch 009] train_loss=0.007980 | val_mean_dailyIC=-0.042930 | best=0.007792@7 | no_improve=2time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 04][epoch 010] train_loss=0.007922 | val_mean_dailyIC=-0.028225 | best=0.007792@7 | no_improve=3time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 04][epoch 011] train_loss=0.007890 | val_mean_dailyIC=-0.018598 | best=0.007792@7 | no_improve=4time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 04][epoch 012] train_loss=0.007803 | val_mean_dailyIC=0.015340 | best=0.015340@12 | no_improve=0time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 04][epoch 013] train_loss=0.007786 | val_mean_dailyIC=-0.042623 | best=0.015340@12 | no_improve=1time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 04][epoch 014] train_loss=0.007716 | val_mean_dailyIC=0.024542 | best=0.024542@14 | no_improve=0time_train=7.5s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 04][epoch 015] train_loss=0.007737 | val_mean_dailyIC=-0.019705 | best=0.024542@14 | no_improve=1time_train=7.2s time_valpred=1.3s time_score=0.1s total=8.6s
# [fold 04][epoch 016] train_loss=0.007647 | val_mean_dailyIC=-0.004834 | best=0.024542@14 | no_improve=2time_train=7.1s time_valpred=1.2s time_score=0.3s total=8.6s
# [fold 04][epoch 017] train_loss=0.007617 | val_mean_dailyIC=-0.003135 | best=0.024542@14 | no_improve=3time_train=6.8s time_valpred=1.0s time_score=0.1s total=8.0s
# [fold 04][epoch 018] train_loss=0.007526 | val_mean_dailyIC=-0.040450 | best=0.024542@14 | no_improve=4time_train=7.3s time_valpred=1.1s time_score=0.2s total=8.6s
# [fold 04][epoch 019] train_loss=0.007458 | val_mean_dailyIC=-0.032858 | best=0.024542@14 | no_improve=5time_train=7.7s time_valpred=1.1s time_score=0.1s total=8.9s
# [fold 04][epoch 020] train_loss=0.007376 | val_mean_dailyIC=0.019701 | best=0.024542@14 | no_improve=6time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 04][epoch 021] train_loss=0.007302 | val_mean_dailyIC=-0.008371 | best=0.024542@14 | no_improve=7time_train=7.7s time_valpred=1.1s time_score=0.2s total=8.9s
# [fold 04][epoch 022] train_loss=0.007259 | val_mean_dailyIC=-0.014935 | best=0.024542@14 | no_improve=8time_train=8.2s time_valpred=1.1s time_score=0.1s total=9.4s
# [fold 04][epoch 023] train_loss=0.007191 | val_mean_dailyIC=-0.007891 | best=0.024542@14 | no_improve=9time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 04][epoch 024] train_loss=0.007117 | val_mean_dailyIC=-0.000356 | best=0.024542@14 | no_improve=10time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 04] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 05][epoch 001] train_loss=0.009608 | val_mean_dailyIC=0.025677 | best=0.025677@1 | no_improve=0time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.5s
# [fold 05][epoch 002] train_loss=0.008287 | val_mean_dailyIC=-0.009342 | best=0.025677@1 | no_improve=1time_train=7.6s time_valpred=1.4s time_score=0.1s total=9.1s
# [fold 05][epoch 003] train_loss=0.008224 | val_mean_dailyIC=-0.000261 | best=0.025677@1 | no_improve=2time_train=7.7s time_valpred=1.4s time_score=0.1s total=9.2s
# [fold 05][epoch 004] train_loss=0.008178 | val_mean_dailyIC=-0.010039 | best=0.025677@1 | no_improve=3time_train=9.3s time_valpred=1.1s time_score=0.1s total=10.5s
# [fold 05][epoch 005] train_loss=0.008073 | val_mean_dailyIC=-0.003123 | best=0.025677@1 | no_improve=4time_train=7.5s time_valpred=1.3s time_score=0.1s total=9.0s
# [fold 05][epoch 006] train_loss=0.008049 | val_mean_dailyIC=0.013374 | best=0.025677@1 | no_improve=5time_train=8.2s time_valpred=1.1s time_score=0.1s total=9.4s
# [fold 05][epoch 007] train_loss=0.007964 | val_mean_dailyIC=0.001258 | best=0.025677@1 | no_improve=6time_train=8.0s time_valpred=1.0s time_score=0.1s total=9.2s
# [fold 05][epoch 008] train_loss=0.007898 | val_mean_dailyIC=0.021117 | best=0.025677@1 | no_improve=7time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 05][epoch 009] train_loss=0.007855 | val_mean_dailyIC=-0.003642 | best=0.025677@1 | no_improve=8time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 05][epoch 010] train_loss=0.007890 | val_mean_dailyIC=0.026099 | best=0.026099@10 | no_improve=0time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 05][epoch 011] train_loss=0.007757 | val_mean_dailyIC=-0.006817 | best=0.026099@10 | no_improve=1time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 05][epoch 012] train_loss=0.007701 | val_mean_dailyIC=-0.001091 | best=0.026099@10 | no_improve=2time_train=7.2s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 05][epoch 013] train_loss=0.007632 | val_mean_dailyIC=-0.000895 | best=0.026099@10 | no_improve=3time_train=7.0s time_valpred=1.0s time_score=0.1s total=8.1s
# [fold 05][epoch 014] train_loss=0.007577 | val_mean_dailyIC=-0.005595 | best=0.026099@10 | no_improve=4time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 05][epoch 015] train_loss=0.007517 | val_mean_dailyIC=0.035682 | best=0.035682@15 | no_improve=0time_train=9.1s time_valpred=1.5s time_score=0.2s total=10.8s
# [fold 05][epoch 016] train_loss=0.007487 | val_mean_dailyIC=0.013774 | best=0.035682@15 | no_improve=1time_train=7.3s time_valpred=1.5s time_score=0.3s total=9.0s
# [fold 05][epoch 017] train_loss=0.007453 | val_mean_dailyIC=0.035040 | best=0.035682@15 | no_improve=2time_train=6.8s time_valpred=1.1s time_score=0.2s total=8.0s
# [fold 05][epoch 018] train_loss=0.007371 | val_mean_dailyIC=0.011043 | best=0.035682@15 | no_improve=3time_train=6.9s time_valpred=1.0s time_score=0.1s total=8.0s
# [fold 05][epoch 019] train_loss=0.007382 | val_mean_dailyIC=0.032298 | best=0.035682@15 | no_improve=4time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 05][epoch 020] train_loss=0.007345 | val_mean_dailyIC=0.013176 | best=0.035682@15 | no_improve=5time_train=7.7s time_valpred=1.5s time_score=0.1s total=9.4s
# [fold 05][epoch 021] train_loss=0.007297 | val_mean_dailyIC=0.000866 | best=0.035682@15 | no_improve=6time_train=6.8s time_valpred=1.0s time_score=0.1s total=8.0s
# [fold 05][epoch 022] train_loss=0.007244 | val_mean_dailyIC=0.007115 | best=0.035682@15 | no_improve=7time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 05][epoch 023] train_loss=0.007205 | val_mean_dailyIC=0.031289 | best=0.035682@15 | no_improve=8time_train=7.8s time_valpred=1.2s time_score=0.1s total=9.0s
# [fold 05][epoch 024] train_loss=0.007113 | val_mean_dailyIC=0.010175 | best=0.035682@15 | no_improve=9time_train=7.9s time_valpred=1.4s time_score=0.1s total=9.5s
# [fold 05][epoch 025] train_loss=0.007078 | val_mean_dailyIC=0.025587 | best=0.035682@15 | no_improve=10time_train=7.0s time_valpred=1.2s time_score=0.1s total=8.2s
# [fold 05] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 06][epoch 001] train_loss=0.011101 | val_mean_dailyIC=0.016594 | best=0.016594@1 | no_improve=0time_train=7.6s time_valpred=1.2s time_score=0.1s total=8.9s
# [fold 06][epoch 002] train_loss=0.009688 | val_mean_dailyIC=0.025665 | best=0.025665@2 | no_improve=0time_train=7.5s time_valpred=1.1s time_score=0.2s total=8.7s
# [fold 06][epoch 003] train_loss=0.009605 | val_mean_dailyIC=0.036169 | best=0.036169@3 | no_improve=0time_train=7.4s time_valpred=1.2s time_score=0.1s total=8.7s
# [fold 06][epoch 004] train_loss=0.009499 | val_mean_dailyIC=0.031907 | best=0.036169@3 | no_improve=1time_train=7.6s time_valpred=1.1s time_score=0.2s total=8.8s
# [fold 06][epoch 005] train_loss=0.009415 | val_mean_dailyIC=0.038388 | best=0.038388@5 | no_improve=0time_train=7.3s time_valpred=1.2s time_score=0.1s total=8.6s
# [fold 06][epoch 006] train_loss=0.009440 | val_mean_dailyIC=0.040308 | best=0.040308@6 | no_improve=0time_train=7.3s time_valpred=1.3s time_score=0.1s total=8.7s
# [fold 06][epoch 007] train_loss=0.009349 | val_mean_dailyIC=0.047343 | best=0.047343@7 | no_improve=0time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 06][epoch 008] train_loss=0.009330 | val_mean_dailyIC=0.042915 | best=0.047343@7 | no_improve=1time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 06][epoch 009] train_loss=0.009257 | val_mean_dailyIC=0.053702 | best=0.053702@9 | no_improve=0time_train=7.0s time_valpred=1.1s time_score=0.1s total=8.2s
# [fold 06][epoch 010] train_loss=0.009235 | val_mean_dailyIC=0.045692 | best=0.053702@9 | no_improve=1time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 06][epoch 011] train_loss=0.009208 | val_mean_dailyIC=0.026751 | best=0.053702@9 | no_improve=2time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 06][epoch 012] train_loss=0.009127 | val_mean_dailyIC=0.042292 | best=0.053702@9 | no_improve=3time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 06][epoch 013] train_loss=0.009123 | val_mean_dailyIC=0.049545 | best=0.053702@9 | no_improve=4time_train=7.3s time_valpred=1.1s time_score=0.2s total=8.6s
# [fold 06][epoch 014] train_loss=0.009016 | val_mean_dailyIC=0.038255 | best=0.053702@9 | no_improve=5time_train=8.0s time_valpred=1.4s time_score=0.1s total=9.6s
# [fold 06][epoch 015] train_loss=0.008934 | val_mean_dailyIC=0.039054 | best=0.053702@9 | no_improve=6time_train=7.5s time_valpred=1.3s time_score=0.1s total=8.9s
# [fold 06][epoch 016] train_loss=0.008912 | val_mean_dailyIC=0.032738 | best=0.053702@9 | no_improve=7time_train=7.4s time_valpred=1.3s time_score=0.1s total=8.9s
# [fold 06][epoch 017] train_loss=0.008819 | val_mean_dailyIC=0.043520 | best=0.053702@9 | no_improve=8time_train=7.6s time_valpred=1.1s time_score=0.1s total=8.8s
# [fold 06][epoch 018] train_loss=0.008788 | val_mean_dailyIC=0.028043 | best=0.053702@9 | no_improve=9time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 06][epoch 019] train_loss=0.008805 | val_mean_dailyIC=0.037307 | best=0.053702@9 | no_improve=10time_train=7.5s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 06] Early stopping: 10 epochs sin mejora.
# Candidate 01 avg_val_mean_dailyIC=0.043242 overrides={'loss_hp': {'ic_lambda': 0.0}}
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 01][epoch 001] train_loss=0.003428 | val_mean_dailyIC=-0.022537 | best=-0.022537@1 | no_improve=0time_train=7.6s time_valpred=1.1s time_score=0.1s total=8.8s
# [fold 01][epoch 002] train_loss=-0.005950 | val_mean_dailyIC=0.019916 | best=0.019916@2 | no_improve=0time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 01][epoch 003] train_loss=-0.008295 | val_mean_dailyIC=-0.010937 | best=0.019916@2 | no_improve=1time_train=6.9s time_valpred=1.1s time_score=0.1s total=8.1s
# [fold 01][epoch 004] train_loss=-0.011645 | val_mean_dailyIC=-0.043434 | best=0.019916@2 | no_improve=2time_train=7.0s time_valpred=1.1s time_score=0.1s total=8.2s
# [fold 01][epoch 005] train_loss=-0.014749 | val_mean_dailyIC=0.009369 | best=0.019916@2 | no_improve=3time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 01][epoch 006] train_loss=-0.017371 | val_mean_dailyIC=0.002895 | best=0.019916@2 | no_improve=4time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 01][epoch 007] train_loss=-0.021620 | val_mean_dailyIC=-0.015807 | best=0.019916@2 | no_improve=5time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 01][epoch 008] train_loss=-0.024970 | val_mean_dailyIC=0.005065 | best=0.019916@2 | no_improve=6time_train=7.6s time_valpred=1.1s time_score=0.1s total=8.8s
# [fold 01][epoch 009] train_loss=-0.027459 | val_mean_dailyIC=0.025219 | best=0.025219@9 | no_improve=0time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.3s
# [fold 01][epoch 010] train_loss=-0.032123 | val_mean_dailyIC=-0.006017 | best=0.025219@9 | no_improve=1time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 01][epoch 011] train_loss=-0.034856 | val_mean_dailyIC=0.001755 | best=0.025219@9 | no_improve=2time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.7s
# [fold 01][epoch 012] train_loss=-0.037654 | val_mean_dailyIC=0.003525 | best=0.025219@9 | no_improve=3time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.3s
# [fold 01][epoch 013] train_loss=-0.040559 | val_mean_dailyIC=0.011680 | best=0.025219@9 | no_improve=4time_train=7.5s time_valpred=1.1s time_score=0.2s total=8.8s
# [fold 01][epoch 014] train_loss=-0.042686 | val_mean_dailyIC=0.029301 | best=0.029301@14 | no_improve=0time_train=8.2s time_valpred=1.0s time_score=0.1s total=9.4s
# [fold 01][epoch 015] train_loss=-0.043964 | val_mean_dailyIC=0.018741 | best=0.029301@14 | no_improve=1time_train=7.4s time_valpred=1.5s time_score=0.2s total=9.1s
# [fold 01][epoch 016] train_loss=-0.046554 | val_mean_dailyIC=0.022561 | best=0.029301@14 | no_improve=2time_train=7.4s time_valpred=1.3s time_score=0.3s total=9.0s
# [fold 01][epoch 017] train_loss=-0.048698 | val_mean_dailyIC=-0.015123 | best=0.029301@14 | no_improve=3time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 01][epoch 018] train_loss=-0.050720 | val_mean_dailyIC=0.015575 | best=0.029301@14 | no_improve=4time_train=7.4s time_valpred=1.0s time_score=0.2s total=8.5s
# [fold 01][epoch 019] train_loss=-0.053159 | val_mean_dailyIC=0.017373 | best=0.029301@14 | no_improve=5time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 01][epoch 020] train_loss=-0.054224 | val_mean_dailyIC=0.030248 | best=0.030248@20 | no_improve=0time_train=7.6s time_valpred=1.0s time_score=0.1s total=8.7s
# [fold 01][epoch 021] train_loss=-0.056170 | val_mean_dailyIC=-0.013503 | best=0.030248@20 | no_improve=1time_train=7.6s time_valpred=1.1s time_score=0.1s total=8.8s
# [fold 01][epoch 022] train_loss=-0.057087 | val_mean_dailyIC=-0.004724 | best=0.030248@20 | no_improve=2time_train=7.8s time_valpred=1.0s time_score=0.1s total=9.0s
# [fold 01][epoch 023] train_loss=-0.058059 | val_mean_dailyIC=0.060874 | best=0.060874@23 | no_improve=0time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 01][epoch 024] train_loss=-0.060040 | val_mean_dailyIC=0.012466 | best=0.060874@23 | no_improve=1time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 01][epoch 025] train_loss=-0.060901 | val_mean_dailyIC=0.022202 | best=0.060874@23 | no_improve=2time_train=7.7s time_valpred=1.2s time_score=0.1s total=9.0s
# [fold 01][epoch 026] train_loss=-0.062179 | val_mean_dailyIC=0.012725 | best=0.060874@23 | no_improve=3time_train=7.5s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 01][epoch 027] train_loss=-0.063143 | val_mean_dailyIC=0.058390 | best=0.060874@23 | no_improve=4time_train=7.6s time_valpred=1.1s time_score=0.1s total=8.8s
# [fold 01][epoch 028] train_loss=-0.065827 | val_mean_dailyIC=0.019360 | best=0.060874@23 | no_improve=5time_train=7.9s time_valpred=1.1s time_score=0.1s total=9.1s
# [fold 01][epoch 029] train_loss=-0.065941 | val_mean_dailyIC=0.055118 | best=0.060874@23 | no_improve=6time_train=7.6s time_valpred=1.2s time_score=0.2s total=9.0s
# [fold 01][epoch 030] train_loss=-0.067342 | val_mean_dailyIC=0.044442 | best=0.060874@23 | no_improve=7time_train=7.2s time_valpred=1.0s time_score=0.2s total=8.4s
# [fold 01][epoch 031] train_loss=-0.068815 | val_mean_dailyIC=0.017131 | best=0.060874@23 | no_improve=8time_train=7.5s time_valpred=1.0s time_score=0.2s total=8.7s
# [fold 01][epoch 032] train_loss=-0.069852 | val_mean_dailyIC=0.030463 | best=0.060874@23 | no_improve=9time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 01][epoch 033] train_loss=-0.069880 | val_mean_dailyIC=0.054039 | best=0.060874@23 | no_improve=10time_train=6.8s time_valpred=1.0s time_score=0.1s total=8.0s
# [fold 01] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 02][epoch 001] train_loss=0.008276 | val_mean_dailyIC=0.020015 | best=0.020015@1 | no_improve=0time_train=8.1s time_valpred=1.1s time_score=0.2s total=9.3s
# [fold 02][epoch 002] train_loss=-0.001719 | val_mean_dailyIC=0.038188 | best=0.038188@2 | no_improve=0time_train=6.9s time_valpred=1.1s time_score=0.1s total=8.1s
# [fold 02][epoch 003] train_loss=-0.005315 | val_mean_dailyIC=0.012581 | best=0.038188@2 | no_improve=1time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.3s
# [fold 02][epoch 004] train_loss=-0.008177 | val_mean_dailyIC=-0.007007 | best=0.038188@2 | no_improve=2time_train=7.2s time_valpred=1.0s time_score=0.2s total=8.3s
# [fold 02][epoch 005] train_loss=-0.011252 | val_mean_dailyIC=0.027904 | best=0.038188@2 | no_improve=3time_train=7.0s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 02][epoch 006] train_loss=-0.017142 | val_mean_dailyIC=0.052474 | best=0.052474@6 | no_improve=0time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 02][epoch 007] train_loss=-0.019853 | val_mean_dailyIC=0.023012 | best=0.052474@6 | no_improve=1time_train=7.0s time_valpred=1.1s time_score=0.1s total=8.2s
# [fold 02][epoch 008] train_loss=-0.022856 | val_mean_dailyIC=0.046274 | best=0.052474@6 | no_improve=2time_train=7.6s time_valpred=1.0s time_score=0.1s total=8.8s
# [fold 02][epoch 009] train_loss=-0.025662 | val_mean_dailyIC=0.003259 | best=0.052474@6 | no_improve=3time_train=7.1s time_valpred=1.0s time_score=0.2s total=8.3s
# [fold 02][epoch 010] train_loss=-0.027388 | val_mean_dailyIC=0.021191 | best=0.052474@6 | no_improve=4time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 02][epoch 011] train_loss=-0.030144 | val_mean_dailyIC=-0.002997 | best=0.052474@6 | no_improve=5time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 02][epoch 012] train_loss=-0.032438 | val_mean_dailyIC=-0.017602 | best=0.052474@6 | no_improve=6time_train=7.2s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 02][epoch 013] train_loss=-0.033788 | val_mean_dailyIC=-0.000272 | best=0.052474@6 | no_improve=7time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 02][epoch 014] train_loss=-0.036883 | val_mean_dailyIC=-0.032418 | best=0.052474@6 | no_improve=8time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 02][epoch 015] train_loss=-0.039177 | val_mean_dailyIC=0.038275 | best=0.052474@6 | no_improve=9time_train=7.4s time_valpred=1.2s time_score=0.1s total=8.7s
# [fold 02][epoch 016] train_loss=-0.042125 | val_mean_dailyIC=-0.005963 | best=0.052474@6 | no_improve=10time_train=7.4s time_valpred=1.3s time_score=0.3s total=9.0s
# [fold 02] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 03][epoch 001] train_loss=0.005883 | val_mean_dailyIC=0.068534 | best=0.068534@1 | no_improve=0time_train=7.4s time_valpred=1.0s time_score=0.2s total=8.6s
# [fold 03][epoch 002] train_loss=-0.002913 | val_mean_dailyIC=0.024217 | best=0.068534@1 | no_improve=1time_train=7.5s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 03][epoch 003] train_loss=-0.007195 | val_mean_dailyIC=0.073522 | best=0.073522@3 | no_improve=0time_train=7.6s time_valpred=1.1s time_score=0.1s total=8.8s
# [fold 03][epoch 004] train_loss=-0.008551 | val_mean_dailyIC=0.054289 | best=0.073522@3 | no_improve=1time_train=7.2s time_valpred=1.3s time_score=0.1s total=8.7s
# [fold 03][epoch 005] train_loss=-0.010592 | val_mean_dailyIC=0.076964 | best=0.076964@5 | no_improve=0time_train=7.5s time_valpred=1.3s time_score=0.1s total=9.0s
# [fold 03][epoch 006] train_loss=-0.014158 | val_mean_dailyIC=0.034764 | best=0.076964@5 | no_improve=1time_train=7.7s time_valpred=1.3s time_score=0.1s total=9.2s
# [fold 03][epoch 007] train_loss=-0.017579 | val_mean_dailyIC=0.093120 | best=0.093120@7 | no_improve=0time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.7s
# [fold 03][epoch 008] train_loss=-0.020490 | val_mean_dailyIC=0.081040 | best=0.093120@7 | no_improve=1time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.3s
# [fold 03][epoch 009] train_loss=-0.025190 | val_mean_dailyIC=0.047889 | best=0.093120@7 | no_improve=2time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.3s
# [fold 03][epoch 010] train_loss=-0.028240 | val_mean_dailyIC=0.046356 | best=0.093120@7 | no_improve=3time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 03][epoch 011] train_loss=-0.031624 | val_mean_dailyIC=-0.002076 | best=0.093120@7 | no_improve=4time_train=7.5s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 03][epoch 012] train_loss=-0.034825 | val_mean_dailyIC=0.072765 | best=0.093120@7 | no_improve=5time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 03][epoch 013] train_loss=-0.036377 | val_mean_dailyIC=0.079913 | best=0.093120@7 | no_improve=6time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 03][epoch 014] train_loss=-0.039836 | val_mean_dailyIC=0.051624 | best=0.093120@7 | no_improve=7time_train=7.2s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 03][epoch 015] train_loss=-0.041502 | val_mean_dailyIC=0.058074 | best=0.093120@7 | no_improve=8time_train=7.6s time_valpred=1.6s time_score=0.1s total=9.3s
# [fold 03][epoch 016] train_loss=-0.043865 | val_mean_dailyIC=-0.001261 | best=0.093120@7 | no_improve=9time_train=7.4s time_valpred=1.3s time_score=0.3s total=9.0s
# [fold 03][epoch 017] train_loss=-0.045127 | val_mean_dailyIC=0.007061 | best=0.093120@7 | no_improve=10time_train=7.4s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 03] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 04][epoch 001] train_loss=0.005841 | val_mean_dailyIC=-0.015578 | best=-0.015578@1 | no_improve=0time_train=7.7s time_valpred=1.0s time_score=0.1s total=8.8s
# [fold 04][epoch 002] train_loss=-0.000809 | val_mean_dailyIC=0.018775 | best=0.018775@2 | no_improve=0time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 04][epoch 003] train_loss=-0.005793 | val_mean_dailyIC=-0.010307 | best=0.018775@2 | no_improve=1time_train=7.0s time_valpred=1.1s time_score=0.1s total=8.2s
# [fold 04][epoch 004] train_loss=-0.007140 | val_mean_dailyIC=0.055180 | best=0.055180@4 | no_improve=0time_train=7.2s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 04][epoch 005] train_loss=-0.008407 | val_mean_dailyIC=0.011687 | best=0.055180@4 | no_improve=1time_train=7.5s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 04][epoch 006] train_loss=-0.010811 | val_mean_dailyIC=0.005713 | best=0.055180@4 | no_improve=2time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.5s
# [fold 04][epoch 007] train_loss=-0.012665 | val_mean_dailyIC=0.002168 | best=0.055180@4 | no_improve=3time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 04][epoch 008] train_loss=-0.016412 | val_mean_dailyIC=0.025755 | best=0.055180@4 | no_improve=4time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 04][epoch 009] train_loss=-0.018093 | val_mean_dailyIC=-0.009396 | best=0.055180@4 | no_improve=5time_train=7.2s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 04][epoch 010] train_loss=-0.021416 | val_mean_dailyIC=0.052554 | best=0.055180@4 | no_improve=6time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.7s
# [fold 04][epoch 011] train_loss=-0.024325 | val_mean_dailyIC=0.017347 | best=0.055180@4 | no_improve=7time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 04][epoch 012] train_loss=-0.026672 | val_mean_dailyIC=0.034483 | best=0.055180@4 | no_improve=8time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 04][epoch 013] train_loss=-0.028319 | val_mean_dailyIC=0.030590 | best=0.055180@4 | no_improve=9time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 04][epoch 014] train_loss=-0.030508 | val_mean_dailyIC=0.043328 | best=0.055180@4 | no_improve=10time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 04] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 05][epoch 001] train_loss=0.006638 | val_mean_dailyIC=-0.009937 | best=-0.009937@1 | no_improve=0time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 05][epoch 002] train_loss=-0.005010 | val_mean_dailyIC=-0.031583 | best=-0.009937@1 | no_improve=1time_train=7.5s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 05][epoch 003] train_loss=-0.008282 | val_mean_dailyIC=0.009540 | best=0.009540@3 | no_improve=0time_train=7.5s time_valpred=1.1s time_score=0.1s total=8.8s
# [fold 05][epoch 004] train_loss=-0.010324 | val_mean_dailyIC=-0.015366 | best=0.009540@3 | no_improve=1time_train=7.6s time_valpred=1.0s time_score=0.1s total=8.8s
# [fold 05][epoch 005] train_loss=-0.012653 | val_mean_dailyIC=0.019328 | best=0.019328@5 | no_improve=0time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 05][epoch 006] train_loss=-0.015254 | val_mean_dailyIC=0.008488 | best=0.019328@5 | no_improve=1time_train=7.6s time_valpred=1.0s time_score=0.2s total=8.7s
# [fold 05][epoch 007] train_loss=-0.017675 | val_mean_dailyIC=0.021732 | best=0.021732@7 | no_improve=0time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 05][epoch 008] train_loss=-0.020603 | val_mean_dailyIC=-0.002408 | best=0.021732@7 | no_improve=1time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 05][epoch 009] train_loss=-0.022932 | val_mean_dailyIC=0.039338 | best=0.039338@9 | no_improve=0time_train=7.0s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 05][epoch 010] train_loss=-0.025964 | val_mean_dailyIC=-0.001816 | best=0.039338@9 | no_improve=1time_train=7.0s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 05][epoch 011] train_loss=-0.027678 | val_mean_dailyIC=-0.007217 | best=0.039338@9 | no_improve=2time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 05][epoch 012] train_loss=-0.029317 | val_mean_dailyIC=-0.019212 | best=0.039338@9 | no_improve=3time_train=6.9s time_valpred=1.0s time_score=0.2s total=8.0s
# [fold 05][epoch 013] train_loss=-0.031272 | val_mean_dailyIC=-0.010527 | best=0.039338@9 | no_improve=4time_train=7.2s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 05][epoch 014] train_loss=-0.033272 | val_mean_dailyIC=-0.003584 | best=0.039338@9 | no_improve=5time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 05][epoch 015] train_loss=-0.035102 | val_mean_dailyIC=-0.006819 | best=0.039338@9 | no_improve=6time_train=7.1s time_valpred=1.2s time_score=0.1s total=8.5s
# [fold 05][epoch 016] train_loss=-0.037070 | val_mean_dailyIC=0.031890 | best=0.039338@9 | no_improve=7time_train=7.4s time_valpred=1.3s time_score=0.1s total=8.8s
# [fold 05][epoch 017] train_loss=-0.038117 | val_mean_dailyIC=0.007087 | best=0.039338@9 | no_improve=8time_train=8.1s time_valpred=1.1s time_score=0.1s total=9.3s
# [fold 05][epoch 018] train_loss=-0.039959 | val_mean_dailyIC=0.001472 | best=0.039338@9 | no_improve=9time_train=7.1s time_valpred=1.1s time_score=0.1s total=8.3s
# [fold 05][epoch 019] train_loss=-0.040685 | val_mean_dailyIC=0.017262 | best=0.039338@9 | no_improve=10time_train=8.5s time_valpred=1.0s time_score=0.1s total=9.7s
# [fold 05] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 06][epoch 001] train_loss=0.009289 | val_mean_dailyIC=0.006628 | best=0.006628@1 | no_improve=0time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 06][epoch 002] train_loss=-0.002845 | val_mean_dailyIC=0.024741 | best=0.024741@2 | no_improve=0time_train=7.1s time_valpred=1.1s time_score=0.2s total=8.3s
# [fold 06][epoch 003] train_loss=-0.007287 | val_mean_dailyIC=0.069409 | best=0.069409@3 | no_improve=0time_train=8.0s time_valpred=1.1s time_score=0.1s total=9.2s
# [fold 06][epoch 004] train_loss=-0.009960 | val_mean_dailyIC=0.059699 | best=0.069409@3 | no_improve=1time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 06][epoch 005] train_loss=-0.011490 | val_mean_dailyIC=0.035332 | best=0.069409@3 | no_improve=2time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.7s
# [fold 06][epoch 006] train_loss=-0.013804 | val_mean_dailyIC=0.048946 | best=0.069409@3 | no_improve=3time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 06][epoch 007] train_loss=-0.014906 | val_mean_dailyIC=0.074384 | best=0.074384@7 | no_improve=0time_train=7.1s time_valpred=1.0s time_score=0.2s total=8.3s
# [fold 06][epoch 008] train_loss=-0.018235 | val_mean_dailyIC=0.048145 | best=0.074384@7 | no_improve=1time_train=6.9s time_valpred=1.0s time_score=0.1s total=8.1s
# [fold 06][epoch 009] train_loss=-0.019895 | val_mean_dailyIC=0.071326 | best=0.074384@7 | no_improve=2time_train=7.5s time_valpred=1.1s time_score=0.2s total=8.8s
# [fold 06][epoch 010] train_loss=-0.022256 | val_mean_dailyIC=0.043585 | best=0.074384@7 | no_improve=3time_train=7.8s time_valpred=1.1s time_score=0.1s total=9.0s
# [fold 06][epoch 011] train_loss=-0.022679 | val_mean_dailyIC=0.057325 | best=0.074384@7 | no_improve=4time_train=7.6s time_valpred=1.1s time_score=0.1s total=8.8s
# [fold 06][epoch 012] train_loss=-0.023886 | val_mean_dailyIC=0.045127 | best=0.074384@7 | no_improve=5time_train=7.7s time_valpred=1.0s time_score=0.1s total=8.8s
# [fold 06][epoch 013] train_loss=-0.025472 | val_mean_dailyIC=0.036157 | best=0.074384@7 | no_improve=6time_train=7.6s time_valpred=1.4s time_score=0.2s total=9.1s
# [fold 06][epoch 014] train_loss=-0.026534 | val_mean_dailyIC=0.065159 | best=0.074384@7 | no_improve=7time_train=7.5s time_valpred=1.1s time_score=0.1s total=8.7s
# [fold 06][epoch 015] train_loss=-0.029057 | val_mean_dailyIC=0.063981 | best=0.074384@7 | no_improve=8time_train=6.9s time_valpred=1.3s time_score=0.1s total=8.3s
# [fold 06][epoch 016] train_loss=-0.029930 | val_mean_dailyIC=0.036314 | best=0.074384@7 | no_improve=9time_train=7.3s time_valpred=1.2s time_score=0.3s total=8.8s
# [fold 06][epoch 017] train_loss=-0.030795 | val_mean_dailyIC=0.066004 | best=0.074384@7 | no_improve=10time_train=7.3s time_valpred=1.0s time_score=0.2s total=8.5s
# [fold 06] Early stopping: 10 epochs sin mejora.
# Candidate 02 avg_val_mean_dailyIC=0.062562 overrides={'loss_hp': {'ic_lambda': 0.2}}
# ==> Seleccionado overrides={'loss_hp': {'ic_lambda': 0.2}} con avg_val_mean_dailyIC=0.062562
#
# === Walk-forward training (por fold) ===
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 01][epoch 001] train_loss=0.004798 | val_mean_dailyIC=-0.095801 | best=-0.095801@1 | no_improve=0time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 01][epoch 002] train_loss=-0.004446 | val_mean_dailyIC=-0.006653 | best=-0.006653@2 | no_improve=0time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 01][epoch 003] train_loss=-0.007368 | val_mean_dailyIC=-0.017154 | best=-0.006653@2 | no_improve=1time_train=7.2s time_valpred=1.1s time_score=0.1s total=8.4s
# [fold 01][epoch 004] train_loss=-0.009411 | val_mean_dailyIC=-0.049760 | best=-0.006653@2 | no_improve=2time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 01][epoch 005] train_loss=-0.010914 | val_mean_dailyIC=-0.005858 | best=-0.005858@5 | no_improve=0time_train=7.8s time_valpred=1.7s time_score=0.1s total=9.6s
# [fold 01][epoch 006] train_loss=-0.012780 | val_mean_dailyIC=-0.017152 | best=-0.005858@5 | no_improve=1time_train=8.3s time_valpred=1.1s time_score=0.1s total=9.5s
# [fold 01][epoch 007] train_loss=-0.014957 | val_mean_dailyIC=-0.028126 | best=-0.005858@5 | no_improve=2time_train=7.0s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 01][epoch 008] train_loss=-0.017610 | val_mean_dailyIC=0.004345 | best=0.004345@8 | no_improve=0time_train=7.3s time_valpred=1.1s time_score=0.1s total=8.5s
# [fold 01][epoch 009] train_loss=-0.020364 | val_mean_dailyIC=-0.045143 | best=0.004345@8 | no_improve=1time_train=7.2s time_valpred=1.0s time_score=0.1s total=8.3s
# [fold 01][epoch 010] train_loss=-0.023497 | val_mean_dailyIC=-0.038596 | best=0.004345@8 | no_improve=2time_train=7.1s time_valpred=1.0s time_score=0.1s total=8.2s
# [fold 01][epoch 011] train_loss=-0.025724 | val_mean_dailyIC=-0.022530 | best=0.004345@8 | no_improve=3time_train=7.3s time_valpred=1.0s time_score=0.1s total=8.4s
# [fold 01][epoch 012] train_loss=-0.028127 | val_mean_dailyIC=-0.003215 | best=0.004345@8 | no_improve=4time_train=8.1s time_valpred=1.1s time_score=0.1s total=9.3s
# [fold 01][epoch 013] train_loss=-0.030609 | val_mean_dailyIC=-0.007870 | best=0.004345@8 | no_improve=5time_train=7.6s time_valpred=1.4s time_score=0.1s total=9.1s
# [fold 01][epoch 014] train_loss=-0.032404 | val_mean_dailyIC=-0.021036 | best=0.004345@8 | no_improve=6time_train=7.6s time_valpred=1.3s time_score=0.1s total=9.1s
# [fold 01][epoch 015] train_loss=-0.034021 | val_mean_dailyIC=0.005748 | best=0.005748@15 | no_improve=0time_train=8.7s time_valpred=1.3s time_score=0.1s total=10.2s
# [fold 01][epoch 016] train_loss=-0.036313 | val_mean_dailyIC=0.012940 | best=0.012940@16 | no_improve=0time_train=7.7s time_valpred=1.3s time_score=0.3s total=9.3s
# [fold 01][epoch 017] train_loss=-0.038247 | val_mean_dailyIC=-0.012158 | best=0.012940@16 | no_improve=1time_train=7.6s time_valpred=1.0s time_score=0.1s total=8.7s
# [fold 01][epoch 018] train_loss=-0.040227 | val_mean_dailyIC=0.056123 | best=0.056123@18 | no_improve=0time_train=7.4s time_valpred=1.0s time_score=0.1s total=8.5s
# [fold 01][epoch 019] train_loss=-0.041484 | val_mean_dailyIC=0.006792 | best=0.056123@18 | no_improve=1time_train=7.8s time_valpred=1.0s time_score=0.1s total=8.9s
# [fold 01][epoch 020] train_loss=-0.043208 | val_mean_dailyIC=-0.000396 | best=0.056123@18 | no_improve=2time_train=7.9s time_valpred=1.1s time_score=0.1s total=9.1s
# [fold 01][epoch 021] train_loss=-0.044249 | val_mean_dailyIC=0.018137 | best=0.056123@18 | no_improve=3time_train=7.5s time_valpred=1.0s time_score=0.1s total=8.6s
# [fold 01][epoch 022] train_loss=-0.046431 | val_mean_dailyIC=0.031846 | best=0.056123@18 | no_improve=4time_train=7.4s time_valpred=1.1s time_score=0.1s total=8.6s
# [fold 01][epoch 023] train_loss=-0.048110 | val_mean_dailyIC=0.009650 | best=0.056123@18 | no_improve=5time_train=7.5s time_valpred=1.1s time_score=0.2s total=8.7s
# [fold 01][epoch 024] train_loss=-0.050084 | val_mean_dailyIC=-0.024665 | best=0.056123@18 | no_improve=6time_train=8.3s time_valpred=1.1s time_score=0.2s total=9.5s
# [fold 01][epoch 025] train_loss=-0.050930 | val_mean_dailyIC=0.018314 | best=0.056123@18 | no_improve=7time_train=9.0s time_valpred=1.3s time_score=0.1s total=10.4s
# [fold 01][epoch 026] train_loss=-0.051890 | val_mean_dailyIC=0.009862 | best=0.056123@18 | no_improve=8time_train=8.0s time_valpred=1.4s time_score=0.2s total=9.5s
# [fold 01][epoch 027] train_loss=-0.053619 | val_mean_dailyIC=-0.015869 | best=0.056123@18 | no_improve=9time_train=7.9s time_valpred=1.3s time_score=0.1s total=9.3s
# [fold 01][epoch 028] train_loss=-0.054187 | val_mean_dailyIC=-0.007624 | best=0.056123@18 | no_improve=10time_train=7.7s time_valpred=1.1s time_score=0.1s total=8.9s
# [fold 01] Early stopping: 10 epochs sin mejora.
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 01] artifact verify: {'max_abs_diff': 0.0, 'mean_abs_diff': 0.0}
# /workspace/finance-modelling/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# [fold 02][epoch 001] train_loss=0.010319 | val_mean_dailyIC=0.012296 | best=0.012296@1 | no_improve=0time_train=7.8s time_valpred=1.1s time_score=0.1s total=9.1s
# [fold 02][epoch 002] train_loss=-0.000573 | val_mean_dailyIC=0.048615 | best=0.048615@2 | no_improve=0time_train=7.8s time_valpred=1.1s time_score=0.2s total=9.1s
